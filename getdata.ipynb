# %%
from dotenv import load_dotenv
import requests
import os
import pandas as pd
from time import sleep
load_dotenv(override=True)
# Out:
# True

# %%
class LolGames:
    def __init__(self):
        self.riot_key=os.environ.get("RIOT_KEY")
        self.url_summoner = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
        self.url_match = "https://europe.api.riotgames.com/lol/match/v5/matches/"
        
        
        self.me_kills = []
        self.me_death= []
        self.me_assists= []
        self.me_role= []
        self.me_minions= []
        self.me_total_damage= []
        self.me_vision_score= []
        self.me_champion= []
        self.me_item0= []
        self.me_item1= []
        self.me_item2= []
        self.me_item3= []
        self.me_item4= []
        self.me_item5= []
        self.me_item6= []
        
        self.ally0_kills= []
        self.ally1_death= []
        self.ally0_assists= []
        self.ally0_role= []
        self.ally0_minions= []
        self.ally0_total_damage= []
        self.ally0_vision_score= []
        self.ally0_champion= []
        self.ally0_item0= []
        self.ally0_item1= []
        self.ally0_item2= []
        self.ally0_item3= []
        self.ally0_item4= []
        self.ally0_item5= []
        self.ally0_item6= []
        
        self.ally1_kills= []
        self.ally1_death= []
        self.ally1_assists= []
        self.ally1_role= []
        self.ally1_minions= []
        self.ally1_total_damage= []
        self.ally1_vision_score= []
        self.ally1_champion= []
        self.ally1_item0= []
        self.ally1_item1= []
        self.ally1_item2= []
        self.ally1_item3= []
        self.ally1_item4= []
        self.ally1_item5= []
        self.ally1_item6= []
        
        self.ally2_kills= []
        self.ally2_death= []
        self.ally2_assists= []
        self.ally2_role= []
        self.ally2_minions= []
        self.ally2_total_damage= []
        self.ally2_vision_score= []
        self.ally2_champion= []
        self.ally2_item0= []
        self.ally2_item1= []
        self.ally2_item2= []
        self.ally2_item3= []
        self.ally2_item4= []
        self.ally2_item5= []
        self.ally2_item6= []
        
        self.ally3_kills= []
        self.ally3_death= []
        self.ally3_assists= []
        self.ally3_role= []
        self.ally3_minions= []
        self.ally3_total_damage= []
        self.ally3_vision_score= []
        self.ally3_champion= []
        self.ally3_item0= []
        self.ally3_item1= []
        self.ally3_item2= []
        self.ally3_item3= []
        self.ally3_item4= []
        self.ally3_item5= []
        self.ally3_item6= []
        
        self.enemy0_kills= []
        self.enemy0_death= []
        self.enemy0_assists= []
        self.enemy0_role= []
        self.enemy0_minions= []
        self.enemy0_total_damage= []
        self.enemy0_vision_score= []
        self.enemy0_champion= []
        self.enemy0_item0= []
        self.enemy0_item1= []
        self.enemy0_item2= []
        self.enemy0_item3= []
        self.enemy0_item4= []
        self.enemy0_item5= []
        self.enemy0_item6= []
        
        self.win = []
    
    def getSummonerPuuid(self, summoner_name):
        full_url = f"{self.url_summoner}{summoner_name}?api_key={self.riot_key}"
        r = requests.get(full_url)
        print(r)
        return r.json()
    def getGamesIdByPuuid(self, puuid):
        full_url = f"{self.url_match}by-puuid/{puuid}/ids?api_key={self.riot_key}"
        print(full_url)
        r = requests.get(full_url)
        return r.json()
    def getGamesDetails(self, gamesId):
        games = {}
        i=0
        for gameId in gamesId:
            full_url = f"{self.url_match}{gameId}?api_key={self.riot_key}"
            game = requests.get(full_url).json()
            games[f"{i}"] = game
            i += 1
        return games
    def getGameDetails(self, games, pseudo):
        gamesDF = []
        for gameNumber in games:
            game = games[f"{gameNumber}"]
            gameParticipants = game["info"]["participants"]
            gameInfo = {}
            for player in gameParticipants:
                if str(player["summonerName"]).lower() == str(pseudo).lower():
                    allyTeamId = player["teamId"]
            
            allyCount = 0
            enemyCount = 0
            for player in gameParticipants:
                
                if str(player["teamId"]).lower() == str(allyTeamId).lower():
                    
                    
                    if player["summonerName"] == pseudo:
                        allyNumber="Me"
                        self.win.append(player["win"])
                    else:
                        allyNumber = f"ally{allyCount}"
                        allyCount += 1
                    
                    if allyNumber=="Me":
                        self.me_kills.append(player["kills"])
                        self.me_death.append(player["death"])
                        self.me_assists.append(2)
                        self.me_role.append(2)
                        self.me_minions.append(2)
                        self.me_total_damage.append(2)
                        self.me_vision_score.append(2)
                        self.me_champion.append(2)
                        self.me_item0.append(2)
                        self.me_item1.append(2)
                        self.me_item2.append(2)
                        self.me_item3.append(2)
                        self.me_item4.append(2)
                        self.me_item5.append(2)
                        self.me_item6.append(2)
                    elif allyNumber=="ally0":
                        self.ally0_kills.append(2)
                        self.ally0_death.append(2)
                        self.ally0_assists.append(2)
                        self.ally0_role.append(2)
                        self.ally0_minions.append(2)
                        self.ally0_total_damage.append(2)
                        self.ally0_vision_score.append(2)
                        self.ally0_champion.append(2)
                        self.ally0_item0.append(2)
                        self.ally0_item1.append(2)
                        self.ally0_item2.append(2)
                        self.ally0_item3.append(2)
                        self.ally0_item4.append(2)
                        self.ally0_item5.append(2)
                        self.ally0_item6.append(2)
                    elif allyNumber=="ally1":
                        self.ally1_kills.append(2)
                        self.ally1_death.append(2)
                        self.ally1_assists.append(2)
                        self.ally1_role.append(2)
                        self.ally1_minions.append(2)
                        self.ally1_total_damage.append(2)
                        self.ally1_vision_score.append(2)
                        self.ally1_champion.append(2)
                        self.ally1_item0.append(2)
                        self.ally1_item1.append(2)
                        self.ally1_item2.append(2)
                        self.ally1_item3.append(2)
                        self.ally1_item4.append(2)
                        self.ally1_item5.append(2)
                        self.ally1_item6.append(2)
                    elif allyNumber=="ally2":
                        self.ally2_kills.append(2)
                        self.ally2_death.append(2)
                        self.ally2_assists.append(2)
                        self.ally2_role.append(2)
                        self.ally2_minions.append(2)
                        self.ally2_total_damage.append(2)
                        self.ally2_vision_score.append(2)
                        self.ally2_champion.append(2)
                        self.ally2_item0.append(2)
                        self.ally2_item1.append(2)
                        self.ally2_item2.append(2)
                        self.ally2_item3.append(2)
                        self.ally2_item4.append(2)
                        self.ally2_item5.append(2)
                        self.ally2_item6.append(2)
                        
                    elif allyNumber=="ally3":
                        self.ally3_kills.append(2)
                        self.ally3_death.append(2)
                        self.ally3_assists.append(2)
                        self.ally3_role.append(2)
                        self.ally3_minions.append(2)
                        self.ally3_total_damage.append(2)
                        self.ally3_vision_score.append(2)
                        self.ally3_champion.append(2)
                        self.ally3_item0.append(2)
                        self.ally3_item1.append(2)
                        self.ally3_item2.append(2)
                        self.ally3_item3.append(2)
                        self.ally3_item4.append(2)
                        self.ally3_item5.append(2)
                        self.ally3_item6.append(2)
                    # gameInfo[f"{allyNumber}_kill"] = player["kills"]
                    # gameInfo[f"{allyNumber}_death"] = player["deaths"]
                    # gameInfo[f"{allyNumber}_assists"] = player["assists"]
                    # gameInfo[f"{allyNumber}_role"] = player["role"]
                    # gameInfo[f"{allyNumber}_minions"] = player["lane"]
                    # gameInfo[f"{allyNumber}_total_damage"] = player["totalMinionsKilled"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["visionScore"]
                    # gameInfo[f"{allyNumber}_champion"] = player["championId"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item0"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item1"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item2"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item3"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item4"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item5"]
                    # gameInfo[f"{allyNumber}_vision_score"] = player["item6"]
                    
                    
                
                        
                else:
                    enemyNumber = f"enemy{enemyCount}"
                    enemyCount += 1
                    if enemyNumber=="enemy0":
                        self.enemy0_kills.append(2)
                        self.enemy0_death.append(2)
                        self.enemy0_assists.append(2)
                        self.enemy0_role.append(2)
                        self.enemy0_minions.append(2)
                        self.enemy0_total_damage.append(2)
                        self.enemy0_vision_score.append(2)
                        self.enemy0_champion.append(2)
                        self.enemy0_item0.append(2)
                        self.enemy0_item1.append(2)
                        self.enemy0_item2.append(2)
                        self.enemy0_item3.append(2)
                        self.enemy0_item4.append(2)
                        self.enemy0_item5.append(2)
                        self.enemy0_item6.append(2)
                    # elif enemyNumber=="enemy1":
                    #     self.enemy1_kills.append(2)
                    #     self.enemy1_death.append(2)
                    #     self.enemy1_assists.append(2)
                    #     self.enemy1_role.append(2)
                    #     self.enemy1_minions.append(2)
                    #     self.enemy1_total_damage.append(2)
                    #     self.enemy1_vision_score.append(2)
                    #     self.enemy1_champion.append(2)
                    #     self.enemy1_item0.append(2)
                    #     self.enemy1_item1.append(2)
                    #     self.enemy1_item2.append(2)
                    #     self.enemy1_item3.append(2)
                    #     self.enemy1_item4.append(2)
                    #     self.enemy1_item5.append(2)
                    #     self.enemy1_item6.append(2)
                        
                        
                    # elif enemyNumber=="enemy2":
                    #     self.enemy2_kills.append(2)
                    #     self.enemy2_death.append(2)
                    #     self.enemy2_assists.append(2)
                    #     self.enemy2_role.append(2)
                    #     self.enemy2_minions.append(2)
                    #     self.enemy2_total_damage.append(2)
                    #     self.enemy2_vision_score.append(2)
                    #     self.enemy2_champion.append(2)
                    #     self.enemy2_item0.append(2)
                    #     self.enemy2_item1.append(2)
                    #     self.enemy2_item2.append(2)
                    #     self.enemy2_item3.append(2)
                    #     self.enemy2_item4.append(2)
                    #     self.enemy2_item5.append(2)
                    #     self.enemy2_item6.append(2)
                    # elif enemyNumber=="enemy3":
                    #     self.enemy3_kills.append(2)
                    #     self.enemy3_death.append(2)
                    #     self.enemy3_assists.append(2)
                    #     self.enemy3_role.append(2)
                    #     self.enemy3_minions.append(2)
                    #     self.enemy3_total_damage.append(2)
                    #     self.enemy3_vision_score.append(2)
                    #     self.enemy3_champion.append(2)
                    #     self.enemy3_item0.append(2)
                    #     self.enemy3_item1.append(2)
                    #     self.enemy3_item2.append(2)
                    #     self.enemy3_item3.append(2)
                    #     self.enemy3_item4.append(2)
                    #     self.enemy3_item5.append(2)
                    #     self.enemy3_item6.append(2)
                    # elif enemyNumber=="enemy4":
                    #     self.enemy4_kills.append(player["kills"])
                    #     self.enemy4_death.append(player["deaths"])
                    #     self.enemy4_assists.append(player["assists"])
                    #     self.enemy4_role.append(player["role"])
                    #     self.enemy4_minions.append(player["role"])
                    #     self.enemy4_total_damage.append(1)
                    #     self.enemy4_vision_score.append(1)
                    #     self.enemy4_champion.append(2)
                    #     self.enemy4_item0.append(1)
                    #     self.enemy4_item1.append(1)
                    #     self.enemy4_item2.append(1)
                    #     self.enemy4_item3.append(1)
                    #     self.enemy4_item4.append(1)
                    #     self.enemy4_item5.append(1)
                    #     self.enemy4_item6.append(1)
                        
                    
                    # gameInfo[f"{enemyNumber}_kill"] = player["kills"]
                    # gameInfo[f"{enemyNumber}_death"] = player["deaths"]
                    # gameInfo[f"{enemyNumber}_assists"] = player["assists"]
                    # gameInfo[f"{enemyNumber}_role"] = player["role"]
                    # gameInfo[f"{enemyNumber}_minions"] = player["lane"]
                    # gameInfo[f"{enemyNumber}_total_damage"] = player["totalMinionsKilled"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["visionScore"]
                    # gameInfo[f"{enemyNumber}_champion"] = player["championId"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item0"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item1"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item2"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item3"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item4"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item5"]
                    # gameInfo[f"{enemyNumber}_vision_score"] = player["item6"]
                
        #     gamesDF.append(gameInfo)
        #     return gameInfo
        # return gamesDF
        return {
            "ally0_kills":[],"ally0_assists":[],"ally0_death":self.[],"ally0_role":self.[],"ally0_champion":self.[],"ally0_vision_score":self.[],"ally0_total_damage":self.[],"ally0_item0":self.[],"ally0_item2":self.[],"ally0_item1":self.[],"ally0_item3":self.[],"ally0_item4":self.[],"ally0_item5":self.[],"ally0_item6":self.[],"ally0_minions":self.[],"win":self.[],
            "ally1_kills":[],"ally1_assists":[],"ally1_death":self.[],"ally1_role":self.[],"ally1_champion":self.[],"ally1_vision_score":self.[],"ally1_total_damage":self.[],"ally1_item0":self.[],"ally1_item2":self.[],"ally1_item1":self.[],"ally1_item3":self.[],"ally1_item4":self.[],"ally1_item5":self.[],"ally1_item6":self.[],"ally1_minions":self.[],
            "ally2_kills":[],"ally2_assists":[],"ally2_death":self.[],"ally2_role":self.[],"ally2_champion":self.[],"ally2_vision_score":self.[],"ally2_total_damage":self.[],"ally2_item0":self.[],"ally2_item2":self.[],"ally2_item1":self.[],"ally2_item3":self.[],"ally2_item4":self.[],"ally2_item5":self.[],"ally2_item6":self.[],"ally2_minions":self.[],
            "ally3_kills":[],"ally3_assists":[],"ally3_death":self.[],"ally3_role":self.[],"ally3_champion":self.[],"ally3_vision_score":self.[],"ally3_total_damage":self.[],"ally3_item0":self.[],"ally3_item2":self.[],"ally3_item1":self.[],"ally3_item3":self.[],"ally3_item4":self.[],"ally3_item5":self.[],"ally3_item6":self.[],"ally3_minions":self.[],
            "me_kills":[],"me_assists":[],"me_death":self.[],"me_role":self.[],"me_champion":self.[],"me_vision_score":self.[],"me_total_damage":self.[],"me_item0":self.[],"me_item2":self.[],"me_item1":self.[],"me_item3":self.[],"me_item4":self.[],"me_item5":self.[],"me_item6":self.[],"me_minions":self.[],
            "enemy4_kills":[],"enemy4_assists":[],"enemy4_death":self.[],"enemy4_role":self.[],"enemy4_champion":self.[],"enemy4_vision_score":self.[],"enemy4_total_damage":self.[],"enemy4_item0":self.[],"enemy4_item2":self.[],"enemy4_item1":self.[],"enemy4_item3":self.[],"enemy4_item4":self.[],"enemy4_item5":self.[],"enemy4_item6":self.[],"enemy4_minions":self.[],
            "enemy0_kills":[],"enemy0_assists":self.[],"enemy0_death":self.[],"enemy0_role":self.[],"enemy0_champion":self.[],"enemy0_vision_score":self.[],"enemy0_total_damage":self.[],"enemy0_item0":self.[],"enemy0_item2":self.[],"enemy0_item1":self.[],"enemy0_item3":self.[],"enemy0_item4":self.[],"enemy0_item5":self.[],"enemy0_item6":self.[],"enemy0_minions":self.[],
            "enemy1_kills":[],"enemy1_assists":self.[],"enemy1_death":self.[],"enemy1_role":self.[],"enemy1_champion":self.[],"enemy1_vision_score":self.[],"enemy1_total_damage":self.[],"enemy1_item0":self.[],"enemy1_item2":self.[],"enemy1_item1":self.[],"enemy1_item3":self.[],"enemy1_item4":self.[],"enemy1_item5":self.[],"enemy1_item6":self.[],"enemy1_minions":self.[],
            "enemy2_kills":[],"enemy2_assists":self.[],"enemy2_death":self.[],"enemy2_role":self.[],"enemy2_champion":self.[],"enemy2_vision_score":self.[],"enemy2_total_damage":self.[],"enemy2_item0":self.[],"enemy2_item2":self.[],"enemy2_item1":self.[],"enemy2_item3":self.[],"enemy2_item4":self.[],"enemy2_item5":self.[],"enemy2_item6":self.[],"enemy2_minions":self.[],
            "enemy3_kills":[],"enemy3_assists":self.[],"enemy3_death":self.[],"enemy3_role":self.[],"enemy3_champion":self.[],"enemy3_vision_score":self.[],"enemy3_total_damage":self.[],"enemy3_item0":self.[],"enemy3_item2":self.[],"enemy3_item1":self.[],"enemy3_item3":self.[],"enemy3_item4":self.[],"enemy3_item5":self.[],"enemy3_item6":self.[],"enemy3_minions":self.[],
                }

# %%
url = f'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Sindil?api_key={os.environ.get("RIOT_KEY")}'
r = requests.get(url)

# %%
r.status_code == 200
# Out:
# True

# %%
class LolGames:
    def __init__(self):
        self.riot_key=os.environ.get("RIOT_KEY")
        self.url_summoner = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
        self.url_match = "https://europe.api.riotgames.com/lol/match/v5/matches/"
        self.gamesData= {
            "gameMode":[],"win":[],
            "ally0_kills":[],"ally0_assists":[],"ally0_death":[],"ally0_role":[],"ally0_champion":[],"ally0_vision_score":[],"ally0_total_damage":[],"ally0_item0":[],"ally0_item2":[],"ally0_item1":[],"ally0_item3":[],"ally0_item4":[],"ally0_item5":[],"ally0_item6":[],"ally0_minions":[],
            "ally1_kills":[],"ally1_assists":[],"ally1_death":[],"ally1_role":[],"ally1_champion":[],"ally1_vision_score":[],"ally1_total_damage":[],"ally1_item0":[],"ally1_item2":[],"ally1_item1":[],"ally1_item3":[],"ally1_item4":[],"ally1_item5":[],"ally1_item6":[],"ally1_minions":[],
            "ally2_kills":[],"ally2_assists":[],"ally2_death":[],"ally2_role":[],"ally2_champion":[],"ally2_vision_score":[],"ally2_total_damage":[],"ally2_item0":[],"ally2_item2":[],"ally2_item1":[],"ally2_item3":[],"ally2_item4":[],"ally2_item5":[],"ally2_item6":[],"ally2_minions":[],
            "ally3_kills":[],"ally3_assists":[],"ally3_death":[],"ally3_role":[],"ally3_champion":[],"ally3_vision_score":[],"ally3_total_damage":[],"ally3_item0":[],"ally3_item2":[],"ally3_item1":[],"ally3_item3":[],"ally3_item4":[],"ally3_item5":[],"ally3_item6":[],"ally3_minions":[],
            "me_kills":[],"me_assists":[],"me_death":[],"me_role":[],"me_champion":[],"me_vision_score":[],"me_total_damage":[],"me_item0":[],"me_item2":[],"me_item1":[],"me_item3":[],"me_item4":[],"me_item5":[],"me_item6":[],"me_minions":[],
            "enemy4_kills":[],"enemy4_assists":[],"enemy4_death":[],"enemy4_role":[],"enemy4_champion":[],"enemy4_vision_score":[],"enemy4_total_damage":[],"enemy4_item0":[],"enemy4_item2":[],"enemy4_item1":[],"enemy4_item3":[],"enemy4_item4":[],"enemy4_item5":[],"enemy4_item6":[],"enemy4_minions":[],
            "enemy0_kills":[],"enemy0_assists":[],"enemy0_death":[],"enemy0_role":[],"enemy0_champion":[],"enemy0_vision_score":[],"enemy0_total_damage":[],"enemy0_item0":[],"enemy0_item2":[],"enemy0_item1":[],"enemy0_item3":[],"enemy0_item4":[],"enemy0_item5":[],"enemy0_item6":[],"enemy0_minions":[],
            "enemy1_kills":[],"enemy1_assists":[],"enemy1_death":[],"enemy1_role":[],"enemy1_champion":[],"enemy1_vision_score":[],"enemy1_total_damage":[],"enemy1_item0":[],"enemy1_item2":[],"enemy1_item1":[],"enemy1_item3":[],"enemy1_item4":[],"enemy1_item5":[],"enemy1_item6":[],"enemy1_minions":[],
            "enemy2_kills":[],"enemy2_assists":[],"enemy2_death":[],"enemy2_role":[],"enemy2_champion":[],"enemy2_vision_score":[],"enemy2_total_damage":[],"enemy2_item0":[],"enemy2_item2":[],"enemy2_item1":[],"enemy2_item3":[],"enemy2_item4":[],"enemy2_item5":[],"enemy2_item6":[],"enemy2_minions":[],
            "enemy3_kills":[],"enemy3_assists":[],"enemy3_death":[],"enemy3_role":[],"enemy3_champion":[],"enemy3_vision_score":[],"enemy3_total_damage":[],"enemy3_item0":[],"enemy3_item2":[],"enemy3_item1":[],"enemy3_item3":[],"enemy3_item4":[],"enemy3_item5":[],"enemy3_item6":[],"enemy3_minions":[],
                
                }
        
        
    
    def getSummonerPuuid(self, summoner_name):
        full_url = f"{self.url_summoner}{summoner_name}?api_key={self.riot_key}"
        r = requests.get(full_url)
        print(r)
        return r.json()
    
    def getGamesIdByPuuid(self, puuid):
        full_url = f"{self.url_match}by-puuid/{puuid}/ids?start=0&count=100&api_key={self.riot_key}"
        print(full_url)
        r = requests.get(full_url)
        return r.json()
    
    def getGamesDetails(self, gamesId):
        games = {}
        i=0
        for gameId in gamesId:
            full_url = f"{self.url_match}{gameId}?api_key={self.riot_key}"
            r = requests.get(full_url)
            
            if r.status_code == 429:
                x = True
                while x:
                    sleep(1)
                    print("bloqué")
                    r = requests.get(full_url)
                    if r.status_code != 429:
                        x=False
            print(r)
                    
            game = r.json()
            games[f"{i}"] = game
            i += 1
            
        return games
    def getGameDetails(self, games, pseudo):
        gamesDF = []
        for gameNumber in games:
            game = games[f"{gameNumber}"]
            gameParticipants = game["info"]["participants"]
            gameInfo = {}
            for player in gameParticipants:
                if str(player["summonerName"]).lower() == str(pseudo).lower():
                    allyTeamId = player["teamId"]
            
            allyCount = 0
            enemyCount = 0
            
            self.gamesData["gameMode"].append(game["info"]["gameMode"]) 
            for player in gameParticipants:
                
                if str(player["teamId"]).lower() == str(allyTeamId).lower():
                    
                    
                    if str(player["summonerName"]).lower() == str(pseudo).lower():
                        allyNumber="me"
                        self.gamesData["win"].append(player["win"])
                        
                    else:
                        allyNumber = f"ally{allyCount}"
                        allyCount += 1
                    

                    self.gamesData[f"{allyNumber}_kills"].append(player["kills"])
                    self.gamesData[f"{allyNumber}_assists"].append(player["assists"])
                    self.gamesData[f"{allyNumber}_death"].append(player["deaths"])
                    self.gamesData[f"{allyNumber}_role"].append(player["role"])
                    self.gamesData[f"{allyNumber}_champion"].append(player["championId"])
                    self.gamesData[f"{allyNumber}_vision_score"].append(player["visionScore"])
                    self.gamesData[f"{allyNumber}_total_damage"].append(player["totalDamageDealt"])
                    self.gamesData[f"{allyNumber}_minions"].append(player["totalMinionsKilled"])
                    self.gamesData[f"{allyNumber}_item0"].append(player["item0"])
                    self.gamesData[f"{allyNumber}_item1"].append(player["item1"])
                    self.gamesData[f"{allyNumber}_item2"].append(player["item2"])
                    self.gamesData[f"{allyNumber}_item3"].append(player["item3"])
                    self.gamesData[f"{allyNumber}_item4"].append(player["item4"])
                    self.gamesData[f"{allyNumber}_item5"].append(player["item5"])
                    self.gamesData[f"{allyNumber}_item6"].append(player["item6"])
                    
                    
                
                        
                else:
                    enemyNumber = f"enemy{enemyCount}"
                    enemyCount += 1
                    self.gamesData[f"{enemyNumber}_kills"].append(player["kills"])
                    self.gamesData[f"{enemyNumber}_assists"].append(player["assists"])
                    self.gamesData[f"{enemyNumber}_death"].append(player["deaths"])
                    self.gamesData[f"{enemyNumber}_role"].append(player["role"])
                    self.gamesData[f"{enemyNumber}_champion"].append(player["championId"])
                    self.gamesData[f"{enemyNumber}_vision_score"].append(player["visionScore"])
                    self.gamesData[f"{enemyNumber}_total_damage"].append(player["totalDamageDealt"])
                    self.gamesData[f"{enemyNumber}_minions"].append(player["totalMinionsKilled"])
                    self.gamesData[f"{enemyNumber}_item0"].append(player["item0"])
                    self.gamesData[f"{enemyNumber}_item1"].append(player["item1"])
                    self.gamesData[f"{enemyNumber}_item2"].append(player["item2"])
                    self.gamesData[f"{enemyNumber}_item3"].append(player["item3"])
                    self.gamesData[f"{enemyNumber}_item4"].append(player["item4"])
                    self.gamesData[f"{enemyNumber}_item5"].append(player["item5"])
                    self.gamesData[f"{enemyNumber}_item6"].append(player["item6"])
                     
        df = pd.DataFrame(data=self.gamesData)
        return df

# %%
def createDF(pseudo):
    #get puuid to get games id
    r = LolGames().getSummonerPuuid(pseudo)
    #get games id
    games = LolGames().getGamesIdByPuuid(r["puuid"])
    #use games id to get all games details
    game = LolGames().getGamesDetails(games)
    #create dict with games infos
    return LolGames().getGameDetails(game, pseudo)
df = createDF("sindil")
# Out:
# <Response [200]>
# https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/bfhqvav0OXU3AyTLTcl_D7_8Jz6D1RP4-ei1UQ3W8Cx1u6hvOibV518TTe-JH5RPOCVvtNokcwkHUA/ids?start=0&count=100&api_key=RGAPI-ab2be7ee-cc49-4eb4-8142-fedf031746bf
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# bloqué
# bloqué
# bloqué
# bloqué
# bloqué
# bloqué
# bloqué
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#    gameMode    win  ally0_kills  ally0_assists  ally0_death ally0_role  \
# 0      ARAM   True            4             35            3    SUPPORT
# 1      ARAM   True           19             20            5    SUPPORT
# 2      ARAM   True           10             37            6       NONE
# 3   CLASSIC   True           11              8            0       SOLO
# 4      ARAM  False            4             11           11    SUPPORT
# ..      ...    ...          ...            ...          ...        ...
# 95     ARAM   True            7             20           17    SUPPORT
# 96     ARAM  False            3             24           13    SUPPORT
# 97     ARAM  False           13             35           13    SUPPORT
# 98     ARAM   True            5             21            6    SUPPORT
# 99     ARAM   True            7             48           14        DUO
#
#     ally0_champion  ally0_vision_score  ally0_total_damage  ally0_item0  \
# ...

# %%
df.to_csv("sindil_lol_first_df.csv", index=False)

# %%
x=True

while x:
    x=False
    print(3)
    
print(22222)
# Out:
# 3
# 22222
